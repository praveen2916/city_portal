# %%
import pandas as pd
import numpy as np
import requests

# %%
Census_2015 = pd.read_excel('Census population by Commune 2015.xlsx',sheet_name='2015',header=7,names=['COM','NAME','POP_15'])
france = pd.read_excel('France GeoIDs.xlsx')
scraped_geoids = pd.read_csv('matching_results.csv',index_col=0)
scraped_geoids.rename({'geonameid':'scraped_geoid'},axis = 1,inplace = True)

# %%
france = france[france['feature_code']=='ADM4']

# %%
Census_uniques = Census_2015.drop_duplicates(subset='NAME',keep = False)

# %%
Census_dups = Census_2015[Census_2015['NAME'].duplicated(keep = False)]

# %%
match_uniques = pd.merge(Census_uniques,france,how = 'left',left_on='NAME',right_on='name')

# %%
match_uniques = match_uniques[['COM','NAME','POP_15','geonameid','name','asciiname']]

# %%
match_uniques_nan = match_uniques[match_uniques['geonameid'].isnull()]

# %%
match_uniques_nan_joined = pd.merge(match_uniques_nan,scraped_geoids,how = 'left',left_on='NAME',right_on='city_names')

# %%
match_uniques_nan.loc[:,'scraped_name']=0
match_uniques_nan.loc[:,'scraped_population']=0
match_uniques_nan.loc[:,'scraped_geonameid']=0
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# //anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
match_uniques_nan[match_uniques_nan['NAME']==match_uniques_nan['scraped_name']]
# Out:
#      index    COM                     NAME  POP_15  geonameid name asciiname  \
# 25    8023  26051        Bézaudun-sur-Bîne      76        NaN  NaN       NaN
# 45   17057  52359                    Nully     161        NaN  NaN       NaN
# 56   24096  67550                    Wœrth    1741        NaN  NaN       NaN
# 83   26936  76479                Nullemont     138        NaN  NaN       NaN
# 120  31485  97119              Petit-Canal    8167        NaN  NaN       NaN
# 122  31487  97121             Pointe-Noire    6280        NaN  NaN       NaN
# 126  31491  97132           Trois-Rivières    8297        NaN  NaN       NaN
# 131  31496  97203             Basse-Pointe    3357        NaN  NaN       NaN
# 154  31519  97232               Le Vauclin    9159        NaN  NaN       NaN
# 166  31531  97312                Sinnamary    2957        NaN  NaN       NaN
# 168  31533  97314                  Ouanary     165        NaN  NaN       NaN
# ...

# %%
#match_uniques_nan['NAME']#==
match_uniques_nan['scraped_name']
# Out:
# 0           L'Abergement-Clémenciat
# 1             L'Abergement-de-Varey
# 2                  L’Épine-aux-Bois
# 3                         Greenwich
# 4               Barri de Sant Josep
# 5            L’Argentière-la-Bessée
# 6                        Le Dévoluy
# 7                        L’Escarène
# 8                         L’Écaille
# 9                         L'Échelle
# 10                      L’Aiguillon
# 11                           L’Herm
# 12      L’Hospitalet-près-l’Andorre
# 13           L'Hospitalet-du-Larzac
# 14                     Montparnasse
# 15                  LIsle-dEspagnac
# 16                        L’Éguille
# 17                        L’Houmeau
# 18                L’Église-aux-Bois
# 19                    L’Étang-Vergy
# 20                    Plœuc-sur-Lié
# 21                      L’Écouvotte
# 22            L’Hôpital-du-Grosbois
# 23         L'Hôpital-Saint-Lieffroy
# 24              L’Isle-sur-le-Doubs
# 25                Bézaudun-sur-Bîne
# ...

# %%
api_key='AIzaSyDr1wlpuQrUd4fz26B-hi9SJh4cAFEXP_8'
user_name = 'TerryYin1777'

# %%
match_uniques_nan = match_uniques_nan.reset_index()

# %%
np.sqrt(0.1)
# Out:
# 0.31622776601683794

# %%
for i in range(match_uniques_nan.shape[0]):#match_uniques_nan_joined.shape[0]):
    
    city_name = match_uniques_nan.loc[i,'NAME']
    geocoding_url='https://maps.googleapis.com/maps/api/geocode/json?address='+city_name+'&key='+api_key
    
    try:
        geocoding_request = requests.get(geocoding_url)
        geocoding_results = geocoding_request.json()
        lat = geocoding_results['results'][0]['geometry']['location']['lat']
        long = geocoding_results['results'][0]['geometry']['location']['lng']

        geonameid_url = 'http://api.geonames.org/findNearbyPlaceNameJSON?lat='+str(lat)+'&lng='+str(long)+'&username='+user_name
        geonameid_request = requests.get(geonameid_url)
        results_geoid = geonameid_request.json()
        matched_name = results_geoid['geonames'][0]['name']
        population = results_geoid['geonames'][0]['population']
        geonameid = results_geoid['geonames'][0]['geonameId']

        match_uniques_nan.loc[i,['scraped_name','scraped_population','scraped_geonameid']] = [matched_name,population,geonameid]
        
    except:
        print('error happened when checking {}'.format(city_name))
    
    if i % 10 == 0:
        print(i, 'cities done!')
# Out:
# 0 cities done!
# 10 cities done!
# 20 cities done!
# 30 cities done!
# 40 cities done!
# error happened when checking Cœur de Causse
# 50 cities done!
# 60 cities done!
# 70 cities done!
# 80 cities done!
# 90 cities done!
# 100 cities done!
# 110 cities done!
# 120 cities done!
# 130 cities done!
# 140 cities done!
# 150 cities done!
# 160 cities done!
# 170 cities done!
# 180 cities done!
# 190 cities done!

# %%
france_dups = france[france['name'].duplicated(keep = False)]

# %%
Census_dups['NAME'].nunique()
# Out:
# 1504

# %%
france_dups['name'].nunique()
# Out:
# 1499

# %%
len(list(set(Census_dups['NAME']).intersection(france_dups['name'])))
# Out:
# 1495

# %%
france_dups[france_dups['name'].isin(Census_dups['NAME'].unique())]
# Out:
#        geonameid                  name             asciiname  \
# 444      6425856              Sanilhac              Sanilhac
# 522      6446336              Santeuil              Santeuil
# 532      6448896                 Billy                 Billy
# 552      6455040           Cassagnoles           Cassagnoles
# 567      6614016             Vitrolles             Vitrolles
# 575      6616576              Savignac              Savignac
# 585      6425089              Mortiers              Mortiers
# 587      6426113           Seraincourt           Seraincourt
# 594      6428417         Saint-Chamant         Saint-Chamant
# 626      6437377          Saint-Gorgon          Saint-Gorgon
# 651      6443777              Nonville              Nonville
# 662      6446593           Châteaufort           Chateaufort
# 677      6451201               Auteuil               Auteuil
# 684      6454273             Longchamp             Longchamp
# ...

# %%
common_unique_cities = list(set(Census_dups['NAME']).intersection(france_dups['name']))

# %%
#census_unique_sub = pd.DataFrame(columns = ['COM','NAME','POP_15'])
count = 0
for c in common_unique_cities:
    #print(c)
    census_sub = Census_dups[Census_dups['NAME']==c]
    census_sub_indexes = census_sub.index
    census_sub_len = len(census_sub_indexes)
    #print(census_sub_indexes)
    
    france_sub = france_dups[france_dups['name']==c]
    france_sub_indexes = france_sub.index
    france_sub_len = len(france_sub_indexes)
    
    if census_sub_len == 0 or france_sub_len == 0:
        continue
    else:
        to_be_encoded = np.min([census_sub_len,france_sub_len])
        
    for i in range(to_be_encoded):
        #print(to_be_encoded)
        census_sub_index = census_sub_indexes[i]
        france_sub_index = france_sub_indexes[i]
        #print(census_sub_index)
        Census_dups.loc[census_sub_index,'NAME'] = Census_dups.loc[census_sub_index,'NAME']+'_'+str(i)
        france_dups.loc[france_sub_index,'name'] = france_dups.loc[france_sub_index,'name']+'_'+str(i) 
        
    count += 1
    if count % 50 == 0:
        print('{} done!'.format(count))
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 10 done!
# 20 done!
# 30 done!
# 40 done!
# 50 done!
# 60 done!
# 70 done!
# 80 done!
# 90 done!
# 100 done!
# 110 done!
# 120 done!
# 130 done!
# 140 done!
# 150 done!
# 160 done!
# 170 done!
# 180 done!
# 190 done!
# 200 done!
# 210 done!
# 220 done!
# 230 done!
# 240 done!
# 250 done!
# 260 done!
# 270 done!
# 280 done!
# 290 done!
# 300 done!
# 310 done!
# 320 done!
# 330 done!
# 340 done!
# 350 done!
# 360 done!
# 370 done!
# 380 done!
# 390 done!
# 400 done!
# 410 done!
# 420 done!
# 430 done!
# 440 done!
# 450 done!
# 460 done!
# 470 done!
# 480 done!
# 490 done!
# 500 done!
# 510 done!
# 520 done!
# 530 done!
# ...

# %%
france_dups.sort_values(by = 'name')
# Out:
#        geonameid            name     asciiname  \
# 23673    6613159     Abancourt_0     Abancourt
# 27596    6452420     Abancourt_1     Abancourt
# 10293    6455366     Aboncourt_0     Aboncourt
# 12560    6613334     Aboncourt_1     Aboncourt
# 5382     6452259         Abzac_0         Abzac
# 26370    6452155         Abzac_1         Abzac
# 3340     6614036       Achères_0       Acheres
# 11276    6455373       Achères_1       Acheres
# 6824     6618157        Aiglun_0        Aiglun
# 27357    6618050        Aiglun_1        Aiglun
# 3176     6452243     Aigremont_0     Aigremont
# 7632     6452531     Aigremont_1     Aigremont
# 12260    6455380     Aigremont_2     Aigremont
# 21759    6452377     Aigremont_3     Aigremont
# 24216    6613163    Aigueperse_0    Aigueperse
# 30887    6452444    Aigueperse_1    Aigueperse
# 8346     6455352  Aigues-Vives_0  Aigues-Vives
# 15388    6616426  Aigues-Vives_1  Aigues-Vives
# 20399    6452111  Aigues-Vives_2  Aigues-Vives
# ...
